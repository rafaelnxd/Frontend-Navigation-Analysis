# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
print(data.describe())
# Out:
#           timestamp  x_position  y_position   time_spent
# count  3.000000e+00    3.000000    3.000000     3.000000
# mean   1.614505e+12  123.333333  223.333333  6333.333333
# std    4.490589e+03   25.166115   25.166115  1527.525232
# min    1.614505e+12  100.000000  200.000000  5000.000000
# 25%    1.614505e+12  110.000000  210.000000  5500.000000
# 50%    1.614505e+12  120.000000  220.000000  6000.000000
# 75%    1.614505e+12  135.000000  235.000000  7000.000000
# max    1.614505e+12  150.000000  250.000000  8000.000000

# %%
#Disperção dos Cliques

plt.scatter(data['x_position'], data['y_position'])
plt.title('Dispersão dos Cliques')
plt.xlabel('Posição X')
plt.ylabel('Posição Y')
plt.show()

# %%
#Distruição do tempo gasto em cada página
